# %%
from bs4 import BeautifulSoup as bs
import requests as req
class BeautifyPage:

    def check_url(self, url):
        headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'}
        return req.get(url, headers=headers)

    def get_markdown(self, resp, type = 'html'):
        return bs(resp.text, type)

    def get_selector(self, soup, selector, get_class=True, target_class='', get_id=True, target_id=''):
        if get_class:
            return soup.find(selector, class_=target_class)
        if get_id:
            return soup.find(selector, id_=target_id)
